# %%
import pandas as pd
linkGit="https://github.com/Journey-of-Success/TAREA-2/raw/main/dataUN_1.csv"
df=pd.read_csv(linkGit)

# %%
df
# Out:
#         Nº                   Country  Human Development Index (HDI)  \
# 0      1.0               Switzerland                          962.0
# 1      2.0                    Norway                          961.0
# 2      3.0                   Iceland                          959.0
# 3      4.0    Hong Kong, China (SAR)                          952.0
# 4      5.0                 Australia                          951.0
# ..     ...                       ...                            ...
# 189  187.0                   Burundi                          426.0
# 190  188.0  Central African Republic                          404.0
# 191  189.0                     Niger                          400.0
# 192  190.0                      Chad                          394.0
# 193  191.0               South Sudan                          385.0
#
#      Life expectancy at birth  Expected years of schooling  \
# 0                        84.0                         16.5
# ...
